# %%
import pickle

enron_data = pickle.load(open("../final_project/final_project_dataset_unix.pkl", "rb"))

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.DataFrame(enron_data)

# %%
df = df.T

# %%
df.drop('TOTAL',inplace=True)

# %%
df
# Out:
#                           bonus  deferral_payments  deferred_income  \
# METTS MARK             600000.0                NaN              NaN
# BAXTER JOHN C         1200000.0          1295738.0       -1386055.0
# ELLIOTT STEVEN         350000.0                NaN        -400729.0
# CORDES WILLIAM R            NaN                NaN              NaN
# HANNON KEVIN P        1500000.0                NaN       -3117011.0
# MORDAUNT KRISTINA M    325000.0                NaN              NaN
# MEYER ROCKFORD G            NaN          1848227.0              NaN
# MCMAHON JEFFREY       2600000.0                NaN              NaN
# HAEDICKE MARK E       1150000.0          2157527.0        -934484.0
# PIPER GREGORY F        400000.0          1130036.0         -33333.0
# HUMPHREY GENE E             NaN          2964506.0              NaN
# NOLES JAMES L               NaN           774401.0              NaN
# BLACHMAN JEREMY M      850000.0                NaN              NaN
# ...

# %%
df[df['poi']==True].count()
# Out:
# bonus                        18
# deferral_payments            18
# deferred_income              18
# director_fees                18
# email_address                18
# exercised_stock_options      18
# expenses                     18
# from_messages                18
# from_poi_to_this_person      18
# from_this_person_to_poi      18
# loan_advances                18
# long_term_incentive          18
# other                        18
# poi                          18
# restricted_stock             18
# restricted_stock_deferred    18
# salary                       18
# shared_receipt_with_poi      18
# to_messages                  18
# total_payments               18
# total_stock_value            18
# dtype: int64

# %%
poi = pd.read_csv("../final_project/poi_names.txt", header=0, names=['nome','sobrenome'])

# %%
poi[poi.nome.str.contains("(y)", regex=False)]
# Out:
#             nome sobrenome
# 0        (y) Lay   Kenneth
# 1   (y) Skilling   Jeffrey
# 19    (y) Forney      John
# 24  (y) Delainey     David

# %%
poi.count()
# Out:
# nome         35
# sobrenome    35
# dtype: int64

# %%
df.loc['PRENTICE JAMES']['total_stock_value']
# Out:
# 1095040

# %%
df.loc['COLWELL WESLEY']['from_this_person_to_poi']
# Out:
# 11

# %%
df.loc['SKILLING JEFFREY K']['exercised_stock_options']
# Out:
# 19250000

# %%
df.loc[['LAY KENNETH L','SKILLING JEFFREY K','FASTOW ANDREW S']]['total_payments']
# Out:
# LAY KENNETH L         103559793
# SKILLING JEFFREY K      8682716
# FASTOW ANDREW S         2424083
# Name: total_payments, dtype: object

# %%
df.replace('NaN',np.NaN,inplace=True)

# %%
df['salary'].count()
# Out:
# 95

# %%
df['email_address'].count()
# Out:
# 111

# %%
df.isna().sum()
# Out:
# bonus                         64
# deferral_payments            107
# deferred_income               97
# director_fees                129
# email_address                 35
# exercised_stock_options       44
# expenses                      51
# from_messages                 60
# from_poi_to_this_person       60
# from_this_person_to_poi       60
# loan_advances                142
# long_term_incentive           80
# other                         53
# poi                            0
# restricted_stock              36
# restricted_stock_deferred    128
# salary                        51
# shared_receipt_with_poi       60
# to_messages                   60
# total_payments                21
# total_stock_value             20
# dtype: int64

# %%
21/146
# Out:
# 0.14383561643835616

# %%
df[df['poi']==True]['total_payments'].isna()
# Out:
# HANNON KEVIN P          False
# COLWELL WESLEY          False
# RIEKER PAULA H          False
# KOPPER MICHAEL J        False
# SHELBY REX              False
# DELAINEY DAVID W        False
# LAY KENNETH L           False
# BOWEN JR RAYMOND M      False
# BELDEN TIMOTHY N        False
# FASTOW ANDREW S         False
# CALGER CHRISTOPHER F    False
# RICE KENNETH D          False
# SKILLING JEFFREY K      False
# YEAGER F SCOTT          False
# HIRKO JOSEPH            False
# KOENIG MARK E           False
# CAUSEY RICHARD A        False
# GLISAN JR BEN F         False
# Name: total_payments, dtype: bool

# %%
df['exercised_stock_options'].max()
# Out:
# 34348384.0

# %%
df['exercised_stock_options'].min()
# Out:
# 3285.0

# %%
df['salary'].max()
# Out:
# 1111258.0

# %%
df['salary'].min()
# Out:
# 477.0

# %%
def featureScaling(arr):
    minx = min(arr)
    rangevalue = max(arr) - min(arr)
    if rangevalue == 0:
        return [1 for x in arr]
    return [float(x - minx)/ rangevalue for x in arr]

# %%
valor200 = float(200000 - df['salary'].min()) / (df['salary'].max() - df['salary'].min())
valor200
# Out:
# 0.17962406631010072

# %%
valor1m = float(1000000 - df['exercised_stock_options'].min()) / (df['exercised_stock_options'].max() - df['exercised_stock_options'].min())
valor1m
# Out:
# 0.029020588934683227

# %%
lista = [115,140,175]
featureScaling(lista)
# Out:
# [0.0, 0.4166666666666667, 1.0]
